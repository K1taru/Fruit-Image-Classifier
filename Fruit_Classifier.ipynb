# %% [markdown]
# ## Fruit Image Classifier - Part 1: Imports & Preprocessing

# %%
# Basic imports
import os, sys
sys.path.append(os.path.abspath("src"))

import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import random

# ML / data processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# TensorFlow
import tensorflow as tf

# %% [markdown]
# #### Reproducibility

# %%
random.seed(42)

np.random.seed(42)

tf.random.set_seed(42)

# %% [markdown]
# #### Detect GPU Available and its Details

# %%
# Imports from src/
from src.detect_gpu import detect_gpu

detect_gpu()

# Check what device TensorFlow sees
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"✅ GPU detected: {gpus}")
else:
    print("❌ No GPU detected. Using CPU.")
# Out:
# 🔍 Checking for GPU...
# 11.8
# True
# Using device: cuda
# ❌ No GPU detected. Running on CPU.
#
# TensorFlow version: 2.20.0
# ⚠️ CUDA/cuDNN version not found — likely running on CPU build of TensorFlow.
# ❌ No GPU detected. Using CPU.

# %% [markdown]
# ### Define dataset path and categories

# %%
DATASET_DIR = "dataset"  # Root dataset folder

SPLITS = ["training", "validation", "test"]

# Your main fruit categories
CATEGORIES = ["Apple", "Banana", "Grapes", "Mango", "Orange"]

# Image size expected for ResNet50
IMG_SIZE = (224, 224)

# Empty lists for data and labels
data_splits = {}
labels_splits = {}

# %% [markdown]
# ### Load and preprocess images

# %%
for split in SPLITS:
    split_data = []
    split_labels = []
    split_path = os.path.join(DATASET_DIR, split)

    print(f"\n📂 Loading {split} data...")

    for category in CATEGORIES:
        category_path = os.path.join(split_path, category)

        # Loop through subfolders (e.g., apple rotten/, apple eaten/)
        for subfolder in os.listdir(category_path):
            subfolder_path = os.path.join(category_path, subfolder)
            if not os.path.isdir(subfolder_path):
                continue

            for img_name in tqdm(os.listdir(subfolder_path), desc=f"{split}/{category}/{subfolder}"):
                img_path = os.path.join(subfolder_path, img_name)
                try:
                    img = cv2.imread(img_path)
                    if img is None:
                        continue
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, IMG_SIZE)
                    img = img.astype(np.float32) / 255.0

                    split_data.append(img)
                    split_labels.append(category)
                except Exception as e:
                    print(f"⚠️ Error loading {img_path}: {e}")

    data_splits[split] = np.array(split_data)
    labels_splits[split] = np.array(split_labels)

    print(f"✅ {split} images loaded: {len(split_data)}")
    print(f"📐 {split} shape: {data_splits[split].shape}")
# Out:
# 📂 Loading training data...
# training/Apple/Apple 10: 100%|██████████| 465/465 [00:04<00:00, 98.48it/s]
# training/Apple/Apple 11: 100%|██████████| 287/287 [00:02<00:00, 106.87it/s]
# training/Apple/Apple 12: 100%|██████████| 310/310 [00:04<00:00, 75.76it/s]
# training/Apple/Apple 13: 100%|██████████| 465/465 [00:05<00:00, 79.11it/s]
# training/Apple/Apple 14: 100%|██████████| 310/310 [00:03<00:00, 86.36it/s]
# training/Apple/Apple 17: 100%|██████████| 489/489 [00:04<00:00, 97.84it/s]
# training/Apple/Apple 18: 100%|██████████| 326/326 [00:03<00:00, 107.63it/s]
# training/Apple/Apple 19: 100%|██████████| 486/486 [00:04<00:00, 99.74it/s]
# training/Apple/Apple 5: 100%|██████████| 294/294 [00:02<00:00, 105.15it/s]
# training/Apple/Apple 7: 100%|██████████| 462/462 [00:04<00:00, 94.91it/s]
# training/Apple/Apple 8: 100%|██████████| 458/458 [00:04<00:00, 94.11it/s]
# training/Apple/Apple 9: 100%|██████████| 463/463 [00:04<00:00, 103.32it/s]
# training/Apple/Apple Red Yellow 2: 100%|██████████| 453/453 [00:04<00:00, 107.97it/s]
# training/Apple/Apple worm 1: 100%|██████████| 465/465 [00:04<00:00, 93.55it/s]
# training/Apple/apple_6: 100%|██████████| 315/315 [00:02<00:00, 111.44it/s]
# training/Apple/apple_braeburn_1: 100%|██████████| 320/320 [00:03<00:00, 100.97it/s]
# training/Apple/apple_crimson_snow_1: 100%|██████████| 318/318 [00:03<00:00, 90.39it/s]
# training/Apple/apple_golden_1: 100%|██████████| 308/308 [00:02<00:00, 105.43it/s]
# training/Apple/apple_golden_2: 100%|██████████| 308/308 [00:02<00:00, 103.87it/s]
# training/Apple/apple_golden_3: 100%|██████████| 316/316 [00:03<00:00, 104.05it/s]
# training/Apple/apple_granny_smith_1: 100%|██████████| 320/320 [00:03<00:00, 102.48it/s]
# training/Apple/apple_pink_lady_1: 100%|██████████| 313/313 [00:03<00:00, 104.18it/s]
# training/Apple/apple_red_1: 100%|██████████| 309/309 [00:03<00:00, 102.71it/s]
# training/Apple/apple_red_2: 100%|██████████| 318/318 [00:03<00:00, 99.61it/s]
# training/Apple/apple_red_3: 100%|██████████| 281/281 [00:02<00:00, 93.97it/s]
# training/Apple/apple_red_delicios_1: 100%|██████████| 300/300 [00:03<00:00, 90.29it/s]
# training/Apple/apple_red_yellow_1: 100%|██████████| 308/308 [00:02<00:00, 104.14it/s]
# training/Banana/Banana 3: 100%|██████████| 154/154 [00:01<00:00, 90.79it/s]
# training/Banana/Banana 4: 100%|██████████| 169/169 [00:01<00:00, 86.73it/s]
# training/Banana/banana fruit: 100%|██████████| 40/40 [00:01<00:00, 30.34it/s]
# training/Banana/overripe: 100%|██████████| 2349/2349 [00:06<00:00, 373.70it/s]
# training/Banana/ripe: 100%|██████████| 3522/3522 [00:08<00:00, 402.25it/s]
# training/Banana/rotten: 100%|██████████| 4020/4020 [00:10<00:00, 379.67it/s]
# training/Banana/unripe: 100%|██████████| 1902/1902 [00:05<00:00, 351.23it/s]
# training/Grapes/grapes fruit: 100%|██████████| 40/40 [00:01<00:00, 28.05it/s]
# training/Grapes/grapes_train_liprofile: 100%|██████████| 849/849 [02:18<00:00,  6.13it/s]
# training/Grapes/ripe grapes: 100%|██████████| 398/398 [00:00<00:00, 680.77it/s]
# training/Grapes/unripe grapes: 100%|██████████| 397/397 [00:00<00:00, 689.86it/s]
# training/Mango/Anwar Ratool: 100%|██████████| 200/200 [00:00<00:00, 238.02it/s]
# training/Mango/Chaunsa (Black): 100%|██████████| 200/200 [00:00<00:00, 227.00it/s]
# training/Mango/Chaunsa (Summer Bahisht): 100%|██████████| 200/200 [00:00<00:00, 220.22it/s]
# training/Mango/Chaunsa (White): 100%|██████████| 200/200 [00:01<00:00, 198.86it/s]
# training/Mango/Class_I: 100%|██████████| 200/200 [00:00<00:00, 245.44it/s]
# training/Mango/Class_II: 100%|██████████| 200/200 [00:00<00:00, 241.83it/s]
# training/Mango/Dosehri: 100%|██████████| 200/200 [00:01<00:00, 195.25it/s]
# training/Mango/Extra_Class: 100%|██████████| 200/200 [00:01<00:00, 188.61it/s]
# training/Mango/Fajri: 100%|██████████| 200/200 [00:01<00:00, 154.46it/s]
# training/Mango/Langra: 100%|██████████| 200/200 [00:00<00:00, 211.82it/s]
# training/Mango/mango fruit: 100%|██████████| 40/40 [00:00<00:00, 61.93it/s]
# training/Mango/ripe mango: 100%|██████████| 399/399 [00:00<00:00, 619.74it/s]
# training/Mango/Sindhri: 100%|██████████| 200/200 [00:01<00:00, 191.61it/s]
# training/Mango/unripe mango: 100%|██████████| 400/400 [00:00<00:00, 623.93it/s]
# training/Orange/orange fruit: 100%|██████████| 40/40 [00:00<00:00, 40.51it/s]
# training/Orange/ripe orange: 100%|██████████| 400/400 [00:00<00:00, 606.78it/s]
# ✅ training images loaded: 27086
# 📐 training shape: (27086, 224, 224, 3)
#
# 📂 Loading validation data...
# validation/Apple/Apple 10: 100%|██████████| 234/234 [00:04<00:00, 49.93it/s]
# validation/Apple/Apple 11: 100%|██████████| 143/143 [00:02<00:00, 56.84it/s]
# validation/Apple/Apple 12: 100%|██████████| 156/156 [00:03<00:00, 42.45it/s]
# validation/Apple/Apple 13: 100%|██████████| 234/234 [00:05<00:00, 43.75it/s]
# validation/Apple/Apple 14: 100%|██████████| 156/156 [00:03<00:00, 44.50it/s]
# validation/Apple/Apple 17: 100%|██████████| 243/243 [00:04<00:00, 49.97it/s]
# validation/Apple/Apple 18: 100%|██████████| 162/162 [00:03<00:00, 53.92it/s]
# validation/Apple/Apple 19: 100%|██████████| 243/243 [00:04<00:00, 52.53it/s]
# validation/Apple/Apple 5: 100%|██████████| 146/146 [00:03<00:00, 39.65it/s]
# validation/Apple/Apple 7: 100%|██████████| 232/232 [00:04<00:00, 52.72it/s]
# validation/Apple/Apple 8: 100%|██████████| 229/229 [00:04<00:00, 49.58it/s]
# validation/Apple/Apple 9: 100%|██████████| 231/231 [00:04<00:00, 54.00it/s]
# validation/Apple/Apple Red Yellow 2: 100%|██████████| 227/227 [00:03<00:00, 58.15it/s]
# validation/Apple/Apple worm 1: 100%|██████████| 231/231 [00:05<00:00, 43.42it/s]
# validation/Apple/apple_6: 100%|██████████| 158/158 [00:02<00:00, 57.84it/s]
# validation/Apple/apple_braeburn_1: 100%|██████████| 160/160 [00:02<00:00, 53.78it/s]
# validation/Apple/apple_crimson_snow_1: 100%|██████████| 159/159 [00:03<00:00, 49.20it/s]
# validation/Apple/apple_golden_1: 100%|██████████| 154/154 [00:02<00:00, 56.93it/s]
# validation/Apple/apple_golden_2: 100%|██████████| 154/154 [00:02<00:00, 55.92it/s]
# validation/Apple/apple_golden_3: 100%|██████████| 158/158 [00:02<00:00, 55.25it/s]
# validation/Apple/apple_granny_smith_1: 100%|██████████| 160/160 [00:03<00:00, 53.18it/s]
# validation/Apple/apple_pink_lady_1: 100%|██████████| 156/156 [00:01<00:00, 86.51it/s]
# validation/Apple/apple_red_1: 100%|██████████| 155/155 [00:02<00:00, 65.29it/s]
# validation/Apple/apple_red_2: 100%|██████████| 159/159 [00:04<00:00, 37.08it/s]
# validation/Apple/apple_red_3: 100%|██████████| 141/141 [00:02<00:00, 49.89it/s]
# validation/Apple/apple_red_delicios_1: 100%|██████████| 150/150 [00:02<00:00, 50.73it/s]
# validation/Apple/apple_red_yellow_1: 100%|██████████| 154/154 [00:02<00:00, 57.55it/s]
# validation/Banana/Banana 3: 100%|██████████| 78/78 [00:01<00:00, 50.61it/s]
# validation/Banana/Banana 4: 100%|██████████| 85/85 [00:01<00:00, 51.71it/s]
# validation/Banana/overripe: 100%|██████████| 229/229 [00:00<00:00, 264.33it/s]
# validation/Banana/ripe: 100%|██████████| 339/339 [00:01<00:00, 268.02it/s]
# validation/Banana/rotten: 100%|██████████| 388/388 [00:01<00:00, 267.41it/s]
# validation/Banana/unripe: 100%|██████████| 167/167 [00:00<00:00, 279.24it/s]
# ✅ validation images loaded: 6171
# 📐 validation shape: (6171, 224, 224, 3)
#
# 📂 Loading test data...
# test/Apple/Apple 10: 100%|██████████| 231/231 [00:04<00:00, 51.51it/s]
# test/Apple/Apple 11: 100%|██████████| 142/142 [00:02<00:00, 56.67it/s]
# test/Apple/Apple 12: 100%|██████████| 154/154 [00:03<00:00, 42.97it/s]
# test/Apple/Apple 13: 100%|██████████| 231/231 [00:05<00:00, 43.91it/s]
# test/Apple/Apple 14: 100%|██████████| 154/154 [00:03<00:00, 45.73it/s]
# test/Apple/Apple 17: 100%|██████████| 243/243 [00:04<00:00, 51.08it/s]
# test/Apple/Apple 18: 100%|██████████| 162/162 [00:02<00:00, 55.34it/s]
# test/Apple/Apple 19: 100%|██████████| 241/241 [00:04<00:00, 53.78it/s]
# test/Apple/Apple 5: 100%|██████████| 146/146 [00:02<00:00, 59.23it/s]
# test/Apple/Apple 7: 100%|██████████| 229/229 [00:04<00:00, 52.44it/s]
# test/Apple/Apple 8: 100%|██████████| 228/228 [00:04<00:00, 48.86it/s]
# test/Apple/Apple 9: 100%|██████████| 231/231 [00:04<00:00, 52.61it/s]
# test/Apple/Apple Red Yellow 2: 100%|██████████| 225/225 [00:03<00:00, 57.90it/s]
# test/Apple/Apple worm 1: 100%|██████████| 231/231 [00:04<00:00, 49.36it/s]
# test/Apple/apple_6: 100%|██████████| 157/157 [00:02<00:00, 59.20it/s]
# test/Apple/apple_braeburn_1: 100%|██████████| 160/160 [00:03<00:00, 50.18it/s]
# test/Apple/apple_crimson_snow_1: 100%|██████████| 159/159 [00:03<00:00, 47.75it/s]
# test/Apple/apple_golden_1: 100%|██████████| 154/154 [00:02<00:00, 56.76it/s]
# test/Apple/apple_golden_2: 100%|██████████| 154/154 [00:02<00:00, 53.66it/s]
# test/Apple/apple_golden_3: 100%|██████████| 158/158 [00:02<00:00, 53.75it/s]
# test/Apple/apple_granny_smith_1: 100%|██████████| 160/160 [00:03<00:00, 51.92it/s]
# test/Apple/apple_pink_lady_1: 100%|██████████| 156/156 [00:02<00:00, 53.82it/s]
# test/Apple/apple_red_1: 100%|██████████| 154/154 [00:02<00:00, 54.59it/s]
# test/Apple/apple_red_2: 100%|██████████| 159/159 [00:02<00:00, 55.93it/s]
# test/Apple/apple_red_3: 100%|██████████| 140/140 [00:02<00:00, 49.69it/s]
# test/Apple/apple_red_delicios_1: 100%|██████████| 150/150 [00:03<00:00, 48.60it/s]
# test/Apple/apple_red_yellow_1: 100%|██████████| 154/154 [00:02<00:00, 56.09it/s]
# test/Banana/Banana 3: 100%|██████████| 77/77 [00:01<00:00, 50.21it/s]
# test/Banana/Banana 4: 100%|██████████| 84/84 [00:01<00:00, 51.01it/s]
# test/Banana/overripe: 100%|██████████| 113/113 [00:00<00:00, 264.54it/s]
# test/Banana/ripe: 100%|██████████| 154/154 [00:00<00:00, 256.52it/s]
# test/Banana/rotten: 100%|██████████| 185/185 [00:00<00:00, 250.95it/s]
# test/Banana/unripe: 100%|██████████| 110/110 [00:00<00:00, 258.95it/s]
# test/Grapes/grapes_test_liprofile: 100%|██████████| 149/149 [00:57<00:00,  2.57it/s]
# ✅ test images loaded: 5735
# 📐 test shape: (5735, 224, 224, 3)

# %%
### Encode labels

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Fit encoder only once (using training labels)
label_encoder = LabelEncoder()
label_encoder.fit(labels_splits["training"])

# Encode all splits
y_train = to_categorical(label_encoder.transform(labels_splits["training"]))
y_val = to_categorical(label_encoder.transform(labels_splits["validation"]))
y_test = to_categorical(label_encoder.transform(labels_splits["test"]))

X_train = data_splits["training"]
X_val = data_splits["validation"]
X_test = data_splits["test"]

print("\n🏷️ Label mapping:")
for i, label in enumerate(label_encoder.classes_):
    print(f"  {i}: {label}")
# Out:
# 🏷️ Label mapping:
#   0: Apple
#   1: Banana
#   2: Grapes
#   3: Mango
#   4: Orange

# %% [markdown]
# ### Show Sample Images

# %%
def show_sample_images(X, y, encoder, n=5):
    plt.figure(figsize=(15, 3))
    for i in range(n):
        idx = np.random.randint(0, len(X))
        plt.subplot(1, n, i+1)
        plt.imshow(X[idx])
        plt.title(encoder.inverse_transform([np.argmax(y[idx])])[0])
        plt.axis("off")
    plt.show()

show_sample_images(X_train, y_train, label_encoder)

# %% [markdown]
# ### Part 2: Data Augmentation
#
# After successfully loading and preprocessing our dataset in **Part 1**, the next steps are to:
#
# 1. **Apply data augmentation** to make the model more robust and reduce overfitting.
# 2. **Prepare the data generators** that will feed the model efficiently.

# %% [markdown]
# ### 📸 Data Augmentation
#
# To make the model generalize better, we apply small random transformations to the training images:
#
# - **Rotation:** up to ±20°
# - **Shifting:** horizontally or vertically up to 10%
# - **Zooming:** up to 20%
# - **Horizontal flip:** mirrors images to simulate variations
#
# These augmentations are applied **on the fly** during training.

# %%
# Part 2: Data Augmentation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data augmentation for training set only
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator()  # no augmentation on validation data
test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(X_train, y_train, batch_size=32, shuffle=True)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32, shuffle=False)
test_generator = test_datagen.flow(X_test, y_test, batch_size=32, shuffle=False)

print("✅ Data augmentation ready.")
# Out:
# ✅ Data augmentation ready.

# %% [markdown]
# ### Visualize Augmented Images (Optional)
#
# Before moving to model training, it’s a good idea to visualize a few augmented samples to ensure the transformations look correct.

# %%
import matplotlib.pyplot as plt

augmented_images, _ = next(train_generator)
plt.figure(figsize=(15, 3))
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(augmented_images[i])
    plt.axis("off")
plt.suptitle("Example Augmented Training Images", fontsize=14)
plt.show()

# %% [markdown]
# ## Part 3 — Model Building (Transfer Learning)

# %% [markdown]
# ### Step 1: Import the required libraries

# %%
# Import the required libraries
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Step 2: Load the Pre-trained Model (ResNet50)

# %%
# Number of classes
num_classes = len(label_encoder.classes_)

# Load pre-trained ResNet50
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ### Step 3: Build the Classification Head

# %%
# Create new model on top of base
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### Step 4: Compile the Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,850,629 (90.98 MB)
#  Trainable params: 262,917 (1.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# 📝 Why categorical_crossentropy?
# Because your labels are one-hot encoded (y_train and y_test).

# %% [markdown]
# ### Step 5: Preprocess and Prepare Data for Training

# %%
# Preprocess the data
print("🔄 Preprocessing training data...")
X_train_prep = preprocess_input(X_train)
print("✅ Training data preprocessing complete.")

print("🔄 Preprocessing test data...")
X_test_prep = preprocess_input(X_test)
print("✅ Test data preprocessing complete.")
# Out:
# 🔄 Preprocessing training data...
# ✅ Training data preprocessing complete.
# 🔄 Preprocessing test data...
# ✅ Test data preprocessing complete.

# %% [markdown]
# ### Step 6: Data Augmentation (Optional)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

datagen.fit(X_train_prep)

# %% [markdown]
# ### Step 7: Train the Model

# %%
batch_size = 32
epochs = 50

import time
from tensorflow.keras.callbacks import Callback

# Custom callback to measure time per epoch
class TimeHistory(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.epoch_start_time
        print(f"⏱️ Time for epoch {epoch + 1}: {epoch_time:.2f} seconds")

# Instantiate the callback
time_callback = TimeHistory()

# Train the model with training and validation generators
with tf.device('/GPU:0'):
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=[time_callback]  # Add the time callback here
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 25
#      19 # Train the model with training and validation generators
#      20 with tf.device('/GPU:0'):
#      21     history = model.fit(
#      22         train_generator,
#      23         validation_data=val_generator,
#      24         epochs=epochs,
# ---> 25         callbacks=[TqdmCallback(), time_callback]  # Add the time callback here
#      26     )
#
# NameError: name 'TqdmCallback' is not defined

# %% [markdown]
# 🧮 Understanding Batch Size and Epochs
#
# When training a deep learning model like a fruit image classifier, two important parameters greatly affect the training process: Batch Size and Epochs.
#
# 🧱 1. Batch Size
#
# Definition:
# Batch size is the number of training samples processed before the model’s internal parameters are updated.
#
# If batch_size = 32, the model looks at 32 images, calculates the error, and then updates the weights.
#
# This happens repeatedly until the model sees all training data (one epoch).
#
# 📌 Effects of Batch Size:
#
# ✅ Smaller batch sizes (e.g., 16–32)
#
# More updates per epoch → can lead to better generalization.
#
# Uses less memory — good for limited GPU/CPU.
#
# Training might be slower overall.
#
# ⚡ Larger batch sizes (e.g., 64–256)
#
# Fewer updates per epoch → may train faster.
#
# Needs more memory (GPU VRAM).
#
# Might generalize less effectively if too large.
#
# 📝 Tip: A common starting point for image classification is batch_size = 32.
#
# 🕒 2. Epochs
#
# Definition:
# An epoch is one complete pass through the entire training dataset.
#
# If you have 1,000 training images and use batch_size = 100,
# then 1 epoch = 10 weight updates (1,000 ÷ 100 = 10).
#
# 📌 Effects of Epochs:
#
# ✅ More epochs → the model learns more patterns.
#
# ⚠️ But too many epochs can lead to overfitting — when the model memorizes the training data and performs poorly on new data.
#
# Too few epochs can lead to underfitting — when the model hasn’t learned enough.
#
# 📝 Tip: Start with 10–20 epochs, then increase if the model is still improving.

# %% [markdown]
# ## Part 4: Model Evaluation and Visualization
# After training the model, it’s important to evaluate its performance and visualize how well it learned over time. This helps us determine if the model is underfitting, overfitting, or performing as expected.

# %% [markdown]
# ### 📊 1. Evaluating the Model
#
# We use the test dataset to check how well the model performs on unseen data.
# This gives us metrics like accuracy and loss, which reflect how close the model’s predictions are to the actual labels.

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"📉 Test Loss: {test_loss:.4f}")

# %% [markdown]
# ### Plotting Training Accuracy and Loss
#
# During training, we stored the accuracy and loss values for each epoch.
# Plotting them helps us visualize how the model improved over time.

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 📝 Interpretation Tips:
#
# 📈 If training accuracy is much higher than validation accuracy → overfitting.
#
# 📉 If both are low → underfitting.
#
# ✅ If both curves improve smoothly and are close → good training.

# %% [markdown]
# ### 3. Confusion Matrix
#
# A confusion matrix provides a more detailed view of classification results.
# It shows how many times the model correctly predicted each class versus how many times it confused it with another.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get predictions on test set
y_true = np.argmax(y_test, axis=1)  # true labels from encoded test set
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# 🧠 How to read the confusion matrix:
#
# Diagonal values = correct predictions ✅
#
# Off-diagonal values = misclassifications ❌
#
# A perfect model would have non-zero values only along the diagonal.
